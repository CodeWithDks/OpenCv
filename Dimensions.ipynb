# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithDks/OpenCv/blob/main/Dimensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Radhe Maa Ji")
# Out:
# Radhe Maa Ji

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/MyPic.jpg")

# %%
if image is not None:
  cv2_imshow(image)
else:
  print("Image not found")
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %%
if image is not None:
  h,w,c = image.shape
  print(f"Image loaded:\nHeight: {h}\nWidth: {w}\nChannels: {c}" )
else:
  print("Could not load image")
# Out:
# Image loaded:
# Height: 1280
# Width: 720
# Channels: 3
